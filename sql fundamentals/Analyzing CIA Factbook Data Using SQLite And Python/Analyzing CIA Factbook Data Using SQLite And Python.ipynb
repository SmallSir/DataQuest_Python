# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('factbook.db')
q = "SELECT * FROM facts"
pd.read_sql_query(q,conn)
# Out:
#       id code                                           name       area  \
# 0      1   af                                    Afghanistan   652230.0
# 1      2   al                                        Albania    28748.0
# 2      3   ag                                        Algeria  2381741.0
# 3      4   an                                        Andorra      468.0
# 4      5   ao                                         Angola  1246700.0
# 5      6   ac                            Antigua and Barbuda      442.0
# 6      7   ar                                      Argentina  2780400.0
# 7      8   am                                        Armenia    29743.0
# 8      9   as                                      Australia  7741220.0
# 9     10   au                                        Austria    83871.0
# 10    11   aj                                     Azerbaijan    86600.0
# 11    12   bf                                   Bahamas, The    13880.0
# ...

# %%
sq1 = "select MIN(population) as min_pop,MAX(population) max_pop,MIN(population_growth) min_pop_growth,MAX(population_growth) max_pop_growth from facts"
pd.read_sql_query(sq1,conn)
# Out:
#    min_pop     max_pop  min_pop_growth  max_pop_growth
# 0        0  7256490011             0.0            4.02

# %%
sq3 = "select * from facts where population = 0"
pd.read_sql_query(sq3,conn)
# Out:
#     id code        name  area  area_land area_water  population  \
# 0  250   ay  Antarctica  None     280000       None           0
#
#   population_growth birth_rate death_rate migration_rate  \
# 0              None       None       None           None
#
#                    created_at                  updated_at
# 0  2015-11-01 13:38:44.885746  2015-11-01 13:38:44.885746

# %%
sq3 = "select * from facts where population = 7256490011"
pd.read_sql_query(sq3,conn)
# Out:
#     id code   name  area area_land area_water  population  population_growth  \
# 0  261   xx  World  None      None       None  7256490011               1.08
#
#    birth_rate  death_rate migration_rate                  created_at  \
# 0        18.6         7.8           None  2015-11-01 13:39:09.910721
#
#                    updated_at
# 0  2015-11-01 13:39:09.910721

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111)
q6 = '''
select population, population_growth, birth_rate, death_rate
from facts
where population != (select max(population) from facts)
and population != (select min(population) from facts);
'''
pd.read_sql_query(q6, conn).hist(ax=ax)
# Out:
# E:\python 3.5\lib\site-packages\IPython\core\interactiveshell.py:2963: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   exec(code_obj, self.user_global_ns, self.user_ns)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DC3BCAF860>,
# ...
#       dtype=object)
